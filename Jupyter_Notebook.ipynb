# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Essentials

# %% [markdown]
# ## Introduction
#
# This notebook covers the basics of Data Science, including key languages, libraries, tools, and fundamental arithmetic operations. It serves as a primer for anyone beginning their journey in the field of Data Science.

# %% [markdown]
# ## Data Science Languages
#
# - Python
# - R
# - SQL
# - Julia
# - Java
# - Scala

# %% [markdown]
# ## Data Science Libraries
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - Keras
# - PyTorch

# %% [markdown]
# ## Data Science Tools
#
# | Tool           | Description                                          |
# |----------------|------------------------------------------------------|
# | Jupyter        | An open-source web application for interactive computing |
# | RStudio        | An integrated development environment for R           |
# | Apache Hadoop  | A framework for distributed storage and processing of big data |
# | Apache Spark   | An open-source distributed general-purpose cluster-computing framework |
# | Tableau        | A powerful data visualization tool                   |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Arithmetic expressions are used to perform mathematical operations such as addition, subtraction, multiplication, and division.

# %%
# Multiply and add numbers
a = 5
b = 4
multiplication = a * b
addition = a + b
multiplication, addition
# Out:
# (20, 9)

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
hours
# Out:
# 2.5

# %% [markdown]
# ## Objectives
#
# - Understand the basic languages used in Data Science
# - Familiarize with key Data Science libraries
# - Learn about essential Data Science tools
# - Practice arithmetic operations in Python
# - Convert time units in Python

# %% [markdown]
# ## Author
#
# Ravinder Joshi
